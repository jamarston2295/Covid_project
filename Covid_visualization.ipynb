# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('final_table.csv',header = 0)
data.head()
# Out:
#        country           gdp  diabetes_rate  median_age  pop_density  \
# 0  Afghanistan  1.910135e+10            9.2        18.9    56.937760
# 1      Albania  1.527808e+10            9.0        32.9   104.612270
# 2      Algeria  1.699882e+11            6.7        28.1    17.730076
# 3      Andorra  3.154058e+09            7.7        44.3   163.842560
# 4       Angola  9.463542e+10            4.5        15.9    24.713053
#
#    sex_ratio  median_income  obesity_rate  healthcare_q_a  smoking_rate  \
# 0   1.063281      458.37073           5.5            32.5          14.4
# 1   1.019369     4201.07700          21.7            78.2          28.7
# 2   1.020274     3098.85180          27.4            63.7          15.6
# 3   1.060000    32030.05500          25.6            94.6          33.5
# 4   0.962207     1028.56470           8.2            40.7           7.8
#
#    total_deaths
# 0          1480
# 1           424
# 2          1809
# 3            57
# 4           219

# %%
sns.pairplot(data);

# %%
sns.pairplot(data, kind="kde")

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(), annot=True, fmt=".2f")
plt.show()
